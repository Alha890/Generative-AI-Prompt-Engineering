# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in c:\users\alha\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: regex in c:\users\alha\anaconda3\lib\site-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests in c:\users\alha\anaconda3\lib\site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alha\anaconda3\lib\site-packages (from requests->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alha\anaconda3\lib\site-packages (from requests->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alha\anaconda3\lib\site-packages (from requests->tiktoken) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alha\anaconda3\lib\site-packages (from requests->tiktoken) (2026.4.22)

# %%
import tiktoken

enc = tiktoken.get_encoding("cl100k_base")

samples = {
    "English Sentence": "Artificial Intelligence is changing the world.",

    "Python Function": """
def add(a, b):
    return a + b
""",

    "Native Language Sentence": "എനിക്ക് പ്രോഗ്രാമിംഗ് വളരെ ഇഷ്ടമാണ്",

    "Number": "1234567",

    "Email Address": "example123@gmail.com",

    "Math Notation": "f(x) = x^2 + 3x - 5"
}

for title, text in samples.items():
    tokens = enc.encode(text)
    token_strings = [enc.decode([token]) for token in tokens]

    print("=" * 50)
    print(title)
    print("Input:", text)
    print("Tokens:", token_strings)
    print("Token Count:", len(tokens))
    print()

print("Explanation:")
print("1. Numbers like 1234567 are grouped into larger chunks instead of single digits.")
print("2. Malayalam text produces more tokens because the tokenizer splits many characters separately.")
# Out:
# ==================================================
# English Sentence
# Input: Artificial Intelligence is changing the world.
# Tokens: ['Art', 'ificial', ' Intelligence', ' is', ' changing', ' the', ' world', '.']
# Token Count: 8
#
# ==================================================
# Python Function
# Input:
# def add(a, b):
#     return a + b
#
# Tokens: ['\n', 'def', ' add', '(a', ',', ' b', '):\n', '   ', ' return', ' a', ' +', ' b', '\n']
# Token Count: 13
#
# ==================================================
# Native Language Sentence
# Input: എനിക്ക് പ്രോഗ്രാമിംഗ് വളരെ ഇഷ്ടമാണ്
# Tokens: ['�', '�', '�', '�', '�', '�', '�', '�', '്�', '�', '്', ' �', '�', '�', '്�', '�', '�', '�', '�', '�', '്�', '�', '�', '�', '�', '�', '�', '�', '�', '�', '�', '�', '്', ' �', '�', '�', '�', '�', '�', '�', '�', '�', ' �', '�', '�', '�', '�', '്�', '�', '�', '�', '�', '�', '�', '�', '്']
# Token Count: 56
#
# ==================================================
# Number
# Input: 1234567
# Tokens: ['123', '456', '7']
# Token Count: 3
#
# ==================================================
# Email Address
# Input: example123@gmail.com
# Tokens: ['example', '123', '@gmail', '.com']
# Token Count: 4
#
# ==================================================
# Math Notation
# Input: f(x) = x^2 + 3x - 5
# Tokens: ['f', '(x', ')', ' =', ' x', '^', '2', ' +', ' ', '3', 'x', ' -', ' ', '5']
# Token Count: 14
#
# Explanation:
# 1. Numbers like 1234567 are grouped into larger chunks instead of single digits.
# 2. Malayalam text produces more tokens because the tokenizer splits many characters separately.
